# %% [markdown]
# Read File
#
# import re
#
# ---
#
#
#  - regular expression syntax
# This module provides regular expression matching operations similar to those found in Perl

# %%
import re

# %%
from collections import Counter

# %%
import string

# %% [markdown]
# create a function

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("./big.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 512665 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 33661 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["love"])
# Out:
# 26

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["love"])
# Out:
# 5.071537943881482e-05

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %% [markdown]
# # Try to identify the mispell word - completed correct spelling

# %%
import numpy as np

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'trasv', 'trtash', 'taash', 'trashg', 'trksh', 'tqrash', 'triash', 'traslh', 'tdash', 'traso', 'erash', 'trah', 'trarh', 'ttrash', 'trasch', 'trasmh', 'trassh', 'trasha', 'vrash', 'trasn', 'mtrash', 'trashc', 'txash', 'thash', 'tragh', 'trkash', 'trajsh', 'traph', 'grash', 'tkash', 'tmash', 'trfash', 'trsash', 'rrash', 'trasht', 'tuash', 'trvsh', 'traoh', 'arash', 'tsash', 'trbsh', 'ktrash', 'trsh', 'tradsh', 'trasc', 'twash', 'traxsh', 'traseh', 'tramsh', 'trasl', 'trdsh', 'hrash', 'trssh', 'trath', 'trasy', 'traszh', 'ttash', 'trjsh', 'trgash', 'tzrash', 'tradh', 'ftrash', 'tdrash', 'tlrash', 'jrash', 'traesh', 'drash', 'tkrash', 'trashp', 'zrash', 'tpash', 'terash', 'ctrash', 'jtrash', 'trashz', 'trdash', 'trashh', 'rtrash', 'trqash', 'trasw', 'rash', 'tyrash', 'trasth', 'trach', 'trashr', 'tcash', 'trawh', 'krash', 'yrash', 'tralsh', 'trashl', 'tsrash', 'trahsh', 'tnrash', 'tfrash', 'tras', 'tarsh', 'trvash', 'transh', 'qtrash', 'trmsh', 'ltrash', 'trasdh', 'trasoh', 'traosh', 'traeh', 'ztrash', 'trsah', 'trash', 'tlash', 'traxh', 'trashs', 'travh', 'trasf', 'xtrash', 'crash', 'trish', 'trashb', 'trashj', 'trwsh', 'trasg', 'tbrash', 'trazsh', 'trasxh', 'tyash', 'xrash', 'trtsh', 'trgsh', 'trasa', 'trasfh', 'trhsh', 'irash', 'trast', 'traqsh', 'trashm', 'trasm', 'tbash', 'trxsh', 'tash', 'otrash', 'trashn', 'trashw', 'tgash', 'vtrash', 'tjash', 'trasrh', 'traih', 'utrash', 'trashv', 'trrsh', 'trzsh', 'torash', 'strash', 'trasuh', 'htrash', 'wtrash', 'trashd', 'tvash', 'trasx', 'turash', 'txrash', 'trasb', 'tralh', 'tratsh', 'btrash', 'tzash', 'trashe', 'trashy', 'tramh', 'itrash', 'frash', 'trabh', 'tragsh', 'dtrash', 'trazh', 'traah', 'trashu', 'trpash', 'trhash', 'traksh', 'trayh', 'toash', 'brash', 'tiash', 'trasp', 'teash', 'tirash', 'trabsh', 'gtrash', 'ytrash', 'thrash', 'trasr', 'trcsh', 'trmash', 'trpsh', 'traish', 'tnash', 'etrash', 'trapsh', 'trajh', 'trafh', 'treash', 'ptrash', 'trush', 'trrash', 'tfash', 'traash', 'travsh', 'tcrash', 'tresh', 'trasyh', 'trauh', 'troash', 'trwash', 'tracsh', 'trase', 'trlash', 'trafsh', 'trahh', 'trnsh', 'trasnh', 'tjrash', 'tarash', 'tryash', 'trass', 'urash', 'tprash', 'trawsh', 'trasah', 
 'troasa', 'trpas', 'trazush', 'bxtrash', 'rtkash', 'trzshb', 'troshs', 'trwsm', 'truskh', 'rtamh', 'vtrashc', 'trsawsh', 'xtrashm', 'ptrlash', 'nrgsh', 'xhash', 'trashjm', 'ftrush', 'trpcsh', 'trgajsh', 'taatsh', 'tvrasx', 'dzrash', 'tbrkash', 'trasawh', 'tsrrsh', 'trzadsh', 'thagsh', 'thasvh', 'trashlt', 'trashyh', 'trwajh', 'tglash', 'trasqfh', 'trarssh', 'tmrasj', 'trdosh', 'trashfr', 'uraskh', 'tnraksh', 'troaesh', 'trashde', 'trhawsh', 'trxsp', 'trasyq', 'utrsah', 'xrpash', 'tracssh', 'ssrash', 'trajsi', 'trsnah', 'turaoh', 'tcaush', 'etrasz', 'rtrach', 'trosa', 'tramsth', 'trabsha', 'ytrase', 'tbashl', 'toashp', 'kdash', 'craoh', 'dtrabh', 'ktrjash', 'rrasph', 'trashbc', 'tfdrash', 'tqralh', 'irasv', 'ztorash', 'tratsk', 'nraqh', 'travah', 'trawlh', 'ztrasha', 'trasthp', 'wrasd', 'krasnh', 'ltraslh', 'trassz', 'trkss', 'tzavh', 'strasih', 'tyrashb', 'turas', 'trashty', 'tfrxash', 'gtrasqh', 'qfash', 'trssch', 'trhaqh', 'trasiz', 'zrashb', 'tvrazsh', 'traxw', 'traisbh', 'trrshp', 'atkrash', 'taasfh', 'wtrafh', 'twasth', 'trwshd', 'ytrgsh', 'jrasx', 'treaesh', 'tfashv', 'trrask', 'trxth', 'rtrapsh', 'trqosh', 'trasve', 'jtrnash', 'traeshg', 'tgashk', 'trcsq', 'tmsash', 'trxashj', 'tkaxh', 'tsras', 'trasvp', 'thrarsh', 'orasv', 'trpashe', 'erasht', 'txrasvh', 'utrashd', 'traow', 'rtradh', 'tragsgh', 'trnsm', 'trasgeh', 'tkrashb', 'trnaseh', 'tcrcash', 'tarasj', 'paash', 'tyakh', 'toramsh', 'tracsc', 'trashks', 'traqshy', 'trashih', 'arashg', 'trcasz', 'tyrtash', 'tfraxsh', 'urasa', 'trahsph', 'vtrashj', 'trazsah', 'trashgm', 'trasue', 'trjashs', 'ttfrash', 'trsash', 'tarabh', 'torashu', 'trawhr', 'tlaeh', 'orasf', 'tgrasht', 'trtoh', 'tpraish', 'tgaish', 'trasvc', 'ersh', 'erlash', 'trasna', 'torsah', 'txaish', 'trjaoh', 'strajh', 'zrasht', 'trasjhu', 'ntroash', 'tessh', 'dtrasht', 'trasks', 'orashs', 'aranh', 'mtrtsh', 'trease', 'trabjh', 'btrafsh', 'trashuz', 'traisph', 'tracsah', 'trbmsh', 'trasgih', 'nrashz', 'tiasi', 'trtasuh', 'zgtrash', 'traxbsh', 'kraih', 'krahh', 'tarzsh', 'trcashu', 'ztrashy', 'trapt', 'trasrj', 'krakh', 'bmash', 'qraish', 'ktsash', 'trashus', 'dtrashi', 'rtabh', 'itrarh', 'trgzh', 'braseh', 'brase', 'ztrasmh', 'trusth', 'tprasg', 'tqrawh', 'lrajsh', 'talrsh' ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")
# Out:
# [('family', 0.00012288726556328208), ('famine', 1.9505915168774932e-06)]
# family is suggested for famile
