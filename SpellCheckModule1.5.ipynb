# %% [markdown]
# Read File
#
# import re
#
# ---
#
#
#  - regular expression syntax
# This module provides regular expression matching operations similar to those found in Perl

# %%
import re

# %%
from collections import Counter

# %%
import string

# %% [markdown]
# create a function

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("./big.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 555410 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 70221 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["love"])
# Out:
# 26

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["love"])
# Out:
# 4.681226481338111e-05

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %% [markdown]
# # Try to identify the mispell word - completed correct spelling

# %%
import numpy as np

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'trast', 'trashl', 'tmash', 'tbash', 'trgash', 'tdash', 'trgsh', 'trahh', 'tryash', 'traxsh', 'trasjh', 'ctrash', 'treash', 'trashm', 'tprash', 'trjash', 'tqash', 'trakh', 'irash', 'trarh', 'traqsh', 'grash', 'tratsh', 'traszh', 'traesh', 'trasx', 'traswh', 'trzash', 'urash', 'strash', 'trwsh', 'trarsh', 'ktrash', 'tralsh', 'ptrash', 'trasbh', 'jtrash', 'trassh', 'tlash', 'trase', 'tmrash', 'utrash', 'twrash', 'travsh', 'trasha', 'traqh', 'tfrash', 'trkash', 'traoh', 'tracsh', 'torash', 'trnsh', 'trasw', 'twash', 'trmash', 'txash', 'trlash', 'tcash', 'rtash', 'thash', 'zrash', 'trashy', 'traso', 'tras', 'tzrash', 'arash', 'trbash', 'trasdh', 'trasvh', 'taash', 'trlsh', 'vtrash', 'trashp', 'trasy', 'trosh', 'trahsh', 'tpash', 'trazsh', 'mrash', 'trath', 'trashc', 'trasi', 'trasr', 'trpash', 'traush', 'trasph', 'tarsh', 'trhsh', 'prash', 'tjrash', 'gtrash', 'tkrash', 'vrash', 'trasf', 'tirash', 'crash', 'trasc', 'xtrash', 'trasih', 'trtsh', 'tnash', 'traseh', 'trasch', 'jrash', 'trasv', 'trasho', 'trashr', 'erash', 'btrash', 'trah', 'trsh', 'trqsh', 'trajh', 'trabh', 'dtrash', 'otrash', 'troash', 'qtrash', 'xrash', 'trahs', 'trashj', 'trasq', 'trash', 'travh', 'teash', 'trrash', 'trasgh', 'terash', 'ttash', 'traysh', 'trdash', 'tralh', 'trask', 'ytrash', 'trapsh', 'transh', 'trayh', 'tgrash', 'trasnh', 'trasmh', 'drash', 'tresh', 'trashe', 'trashh', 'trashk', 'tvrash', 'trcsh', 'trnash', 'trasz', 'trajsh', 'traksh', 'trasd', 'tiash', 'ztrash', 'tcrash', 'trasxh', 'trasqh', 'tvash', 'nrash', 'trass', 'trasl', 'tash', 'tsash', 'tyash', 'srash', 'traph', 'trasm', 'ttrash', 'ftrash', 'turash', 'trpsh', 'trtash', 'trafsh', 'tqrash', 'traish', 'tragh', 'tramh', 'tranh', 'txrash', 'trasb', 'rrash', 'htrash', 'trasoh', 'brash', 'trazh', 'tyrash', 'traosh', 'trashs', 'lrash', 'trashi', 'orash', 'wrash', 'etrash', 'trafh', 'atrash', 'tkash', 'trsash', 'trashb', 'tjash', 'trauh', 'traslh', 'toash', 'tfash', 'trashu', 'trhash', 'traah', 'trashw', 'traxh', 'wtrash', 'trcash', 'frash', 'trzsh', 'trxash', 'traskh', 'tdrash', 'hrash', 'tradh', 'tgash', 'trmsh', 'trush', 'thrash', 'trqash', 'trish', 'tnrash', 'ltrash', 'trbsh', 'tuash', 'trawh', 'trasu', 'trysh', 'trasyh', 'trasg', 'qrash', 'trasp', 'rtrash', 'traash', 'trabsh', 'trasuh', 'trsah', 'trvsh', 'trasht', 'trdsh', 'traih', 'tramsh', 'trasth', 'yrash', 'traeh', 'truash', 'tarash', 'trashv', 'trawsh', 'trksh', 'trashz', 'trasah', 'trxsh', 'trach', 'tzash', 'trasa', 'trasn', 'trvash', 'triash', 'trfash', 'krash', 'trrsh', 'tragsh', 'tsrash', 'trssh', 'trasj', 'rash', 'trashq', 'ntrash', 'trwash', 'tradsh', 'tlrash', 'trashn', 'trashx', 'trfsh', 'trashd', 'itrash', 'tbrash', 'trashg', 'trashf', 'mtrash', 'trasfh', 'trjsh', 'trasrh'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'trashpb', 'lrawh', 'tbrasgh', 'tyraswh', 'tpraush', 'ptraoh', 'ntdash', 'tgawsh', 'traspah', 'tqasl', 'tvrnsh', 'traxsb', 'trsasdh', 'lrast', 'trajhh', 'trehash', 'tvradh', 'trjgh', 'tlah', 'tiramsh', 'ktraish', 'traushk', 'trmsph', 'ttaih', 'toaso', 'treasn', 'troafh', 'trausha', 'tpsah', 'tiazh', 'tryaseh', 'trafxh', 'itrajh', 'iraah', 'ptrasih', 'tbrayh', 'taayh', 'trashco', 'yrasdh', 'travsc', 'trashpw', 'otrosh', 'trasjhg', 'xtash', 'trwsc', 'trgamh', 'tzakh', 'stlash', 'trvshh', 'trcsf', 'traqwsh', 'thasih', 'trzshr', 'twrtash', 'trnasy', 'trusrh', 'tcrashl', 'trmaesh', 'trashxv', 'tzragsh', 'vtiash', 'trasen', 'towrash', 'tvsrash', 'tcqsh', 'prashz', 'trxsb', 'trdhh', 'tsasr', 'tqraash', 'traqht', 'nrjsh', 'mradh', 'trsase', 'trarshe', 'xtmash', 'trasra', 'qrasw', 'atrashe', 'hrasgh', 'tyeash', 'tnraph', 'rcsh', 'tvrass', 'htrasoh', 'traymsh', 'trlsjh', 'wtralh', 'urajh', 'tirasph', 'atrazh', 'kash', 'ctrashv', 'oratsh', 'odtrash', 'toafh', 'tlashg', 'tiacsh', 'srwsh', 'tlansh', 'tpzash', 'drasfh', 'tranq', 'syrash', 'tramhm', 'prazh', 'trassch', 'trwyash', 'trfswh', 'qtash', 'krahs', 'xtrasha', 'tvrrsh', 'trasihm', 'txuash', 'trahvh', 'tjrksh', 'trashmr', 'tdqrash', 'rjrash', 'rtrasb', 'traytsh', 'trjask', 'tjraswh', 'utgrash', 'tcrasy', 'trmrash', 'tcach', 'teashg', 'ttramh', 'ttrawh', 'thraqsh', 'tcashi', 'tnrush', 'tradq', 'trzzash', 'zranh', 'xtrashn', 'ntruash', 'tlaseh', 'tnjsh', 'frashe', 'tmksh', 'tlasb', 'zwrash', 'ftraesh', 'yrafsh', 'tdransh', 'trascj', 'traep', 'tiatsh', 'tmbsh', 'tvrlash', 'trusch', 'trwwsh', 'rtrashe', 'rzsh', 'wjash', 'tauash', 'yragsh', 'ktgrash', 'tralhk', 'tuashm', 'trannsh', 'ngash', 'wrzsh', 'tnrosh', 'trmadh', 'tarasj', 'trmish', 'taarsh', 'tyrasyh', 'jtraxh', 'tradshs', 'tzasdh', 'tarrsh', 'dtrasq', 'xrzsh', 'trawwh', 'tase', 'trrssh', 'rtroash', 'trasaqh', 'taxh', 'tvrasch', 'trthash', 'trdyash', 'tprashr', 'trhs', 'ptrasq', 'trabp', 'dtyash', 'ctrashu', 'ctcash', 'tbrasfh', 'traxsbh', 'yrzsh', 'tjrasth', 'xvrash', 'trtadsh', 'ljash', 'traesah', 'tfasch', 'jrasl', 'trkagh', 'vtoash', 'trasjyh', 'tarfsh', 'xtrasd', 'traoshf', 'tiraskh', 'trdaish', 'trauw', 'xtrasrh', 'trasmq', 'yzrash', 'wdtrash', 'trabth', 'zrvash', 'vthrash', 'trtadh', 'tgraqsh', 'uraash', 'triashi', 'htrpash', 'traghx', 'tcrash', 'litrash', 'trarshl', 'tzirash', 'hrasdh', 'mtrjsh', 'trixh', 'triassh', 'ltnash', 'brwsh', 'mrasm', 'tssh', 'tlralsh', 'yxtrash', 'tepsh', 'rtirash', 'trrsoh', 'tgasuh', 'tgmrash', 'trauv', 'tdfsh', 'traashd', 'tolsh', 'trwaesh', 'drish', 'trwsha', 'tcassh', 'vraslh', 'trvsbh', 'ras', 'traezh', 'tarsch', 'orast', 'tgash', 'traahg', 'tbrqsh', 'nrayh', 'qtrast', 'tmrwsh', 'grach', 'trasghe', 'ntransh', 'thrarsh', 'trsah', 'trancsh', 'trvaesh', 'tnashw', 'ptrashu', 'trajb', 'orabsh', 'gtrbsh', 'trashdr', 'tsosh', 'traoph', 'ttasy', 'tdrasdh', 'trafsl', 'vtrwsh', 'trabsoh', 'tdrashi', 'traoy', 'trunsh', 'grashb', 'trxashk', 'ptjash', 'trsasht', 'trcxh', 'trtsc', 'truasf', 'wrgash', 'mrasd', 'travhv', 'traax', 'tgrafh', 'trasiqh', 'trasvhv', 'tkrfash', 'ltrashs', 'nctrash', 'dtrdsh', 'qtrabsh', 'ftrasm', 'tjrcash', 'trasngh', 'xlash', 'tpasi', 'tryhs', 'trawsy', 'wtrasbh', 'ftrashh', 'twash', 'tuvsh', 'trayhx', 'troahh', 'trlshe', 'itraeh', 'rrmsh', 'trsat', 'tqath', 'ictrash', 'traspdh', 'trabhw', 'traasd', 'tmaash', 'treaswh', 'trkasf', 'tuosh', 'ttrashn', 'tzaswh', 'toalsh', 'trasnhw', 'trkasp', 'tqamh', 'yranh', 'drafsh', 'gtrashq', 'trhqsh', 'trabgh', 'traksc', 'trpgash', 'trfsha', 'trdasx', 'tlrarh', 'traln', 'traio', 'jtrashm', 'tzasb', 'trashac', 'tcrasrh', 'mraesh', 'torasnh', 'trasihp', 'dtgash', 'rrasm', 'trxsu', 'wmash', 'turasp', 'traqhj', 'orasu', 'sralsh', 'trvvash', 'twraskh', 'trabhl', 'triaseh', 'trpsj', 'krasht', 'trxsn', 'tuafsh', 'ytqrash', 'traslhz', 'trashrb', 'ktraseh', 'utrasm', 'trdah', 'trashqq', 'trvth', 'twask', 'ftrasq', 'trxshv', 'tdashr', 'tragsfh', 'trasfb', 'taazsh', 'jriash', 'uruash', 'tdaxh', 'tgrfsh', 'orasp', 'tasm', 'trmahh', 'trashoh', 'traqgsh',  ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")
# Out:
# [('famine', 3.600943447183162e-06), ('family', 0.0001134297185862696)]
# family is suggested for famile

# %% [markdown]
# # Optimize commands

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters] 

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("./big.txt")

# %%
checker.check("dvck")
# Out:
# [('dock', 1.2603302065141068e-05),
#  ('deck', 1.800471723591581e-06),
#  ('vck', 1.800471723591581e-06),
#  ('dvc', 1.800471723591581e-06),
#  ('dick', 1.800471723591581e-06),
#  ('duck', 1.800471723591581e-06)]
